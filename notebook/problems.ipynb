# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
import random

# number of simulations
n_simulations = 1000

# counter for favorable outcomes
favorable = 0

for _ in range(n_simulations):
    # roll two dice
    die1 = random.randint(1, 6)
    die2 = random.randint(1, 6)
    total = die1 + die2
    
    # check condition: even OR greater than 7
    if total % 2 == 0 or total > 7:
        favorable += 1

# estimated probability
probability = favorable / n_simulations
print("Estimated Probability:", probability)
# Out:
# Estimated Probability: 0.69

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. Take all of the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
import random

# probabilities of each color
colors = ["white"] * 10 + ["red"] * 20 + ["green"] * 30

n_simulations = 1000
count_case1 = 0  # 3 white and 2 red
count_case2 = 0  # all same color

for _ in range(n_simulations):
    # draw 5 balls with replacement
    draws = [random.choice(colors) for _ in range(5)]
    
    # case 1: exactly 3 white and 2 red
    if draws.count("white") == 3 and draws.count("red") == 2:
        count_case1 += 1
    
    # case 2: all of the same color
    if len(set(draws)) == 1:
        count_case2 += 1

# estimated probabilities
prob_case1 = count_case1 / n_simulations
prob_case2 = count_case2 / n_simulations

print("Estimated Probability (3 white, 2 red):", prob_case1)
print("Estimated Probability (all same color):", prob_case2)
# Out:
# Estimated Probability (3 white, 2 red): 0.007
# Estimated Probability (all same color): 0.04
